# %% [markdown]
# # TwiZlatan

# %% [markdown]
# For today's lesson, we're gonna learn something practical: Twitter scraping with the [Twython](https://twython.readthedocs.io/en/latest/usage/install.html), [Tweepy](https://docs.tweepy.org/en/stable/) and [Snscrape](https://github.com/JustAnotherArchivist/snscrape), packages, and sentiment analysis with [TextBlob](https://textblob.readthedocs.io/en/dev/). We'll also plot a nice [wordcloud](https://pypi.org/project/wordcloud/)!
#
# The topic will be, as some of you already guessed from the name of the notebook, this guy:

# %% [markdown]
# ![image](images/zlatan.PNG)

# %% [markdown]
# (If you don't know who he is, which is highly problematic, here is his [Wikipedia page](https://en.wikipedia.org/wiki/Zlatan_Ibrahimovi%C4%87))
#
# We're going to grab Tweets relating to/tagging him, to get an idea of how the public perception of ~~God~~ Zlatan has changed over time.

# %% [markdown]
# ## Lesson plan
#
# 1. Twython
# 2. Tweepy
# 3. Snscrape
# 4. Sentiment analysis

# %% [markdown]
# Let's start by importing the required packages:

# %%
from twython import Twython, TwythonError
import tweepy
import configparser
import numpy as np
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools
from textblob import TextBlob
import nltk
nltk.download('vader_lexicon')
import string
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\fbindi\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# Then, you need to generate an application to connect to the Twitter API, which can be done by going to [this website](https://apps.twitter.com). Store the credentials of your application in a safe location, preferrably an .ini file.
#
# You will be required to apply for a Twitter Developer account (and possibly to upgrade it to gain Elevated access).

# %%
config = configparser.ConfigParser()
config.read(r'H:\credentials\config.ini') # Your .ini file with your credentials

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']
bearer_token = config['twitter']['bearer_token'] # We need to escape the "%" sign with another "%" sign in the .ini file
access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %% [markdown]
# ### 1. Twython

# %% [markdown]
# We create a connection and perform the search:

# %%
connection = Twython(
    api_key,
    api_key_secret
)

# %%
results = connection.search(q='#ibrahimovic',count=10)

# %% [markdown]
# The query in the cell above is quite simple: we are simply looking for the first 10 tweets that contain the hasthag `#ibrahimovic`.

# %% [markdown]
# `reults` is a dictionary of dictionaries. The actual tweets are stored under the key `'statuses'`, which yields another dictionary; the key `'text'` gives the text of the tweets.

# %%
for i,tweet in enumerate(results['statuses']):
    print('\n')
    print(f'Tweet{i+1}')
    print(tweet['text'])
# Out:
# Tweet1
# Ich freue mich auf euch 🫶🏼
# ➡️ https://t.co/gOL8byVEc2!
#
# #twitch #StreamingNow #Zlatan #ibrahimovic https://t.co/u80q1bFX1H
#
#
# Tweet2
# Retroscena #Quagliarella- #Ibrahimovic
# https://t.co/2mwKSmnbiY
#
#
# Tweet3
# Milan: ecco quando rientra Ibrahimovic.
#
# Le news -) https://t.co/L2URuIJNMq
#
# #Milan #Acmilan #Ibrahimovic
#
#
# Tweet4
# Milan: ecco quando rientra Ibrahimovic.
#
# Le news -) https://t.co/zg2lvLj1tR
#
# #Milan #Acmilan #Ibrahimovic
#
#
# Tweet5
# RT @TeamSerieA_fr: 🚨 Zlatan #Ibrahimovic révèle le coéquipier qui l'a le plus impressionné ! https://t.co/E0yLlUL4HV
#
#
# Tweet6
# #Ibrahimovic
# Can you believe this is a 41 year old athlete？😮😮😮😮 https://t.co/lj2hc0tMGd
#
#
# Tweet7
# 6-1-22 #SerieA
# #MilanRoma 3-1
# 8' Giroud, 17' Messias, 40' Abraham, 82' Leao
# #Maignan, #Florenzi (#Conti), #Kalulu,… https://t.co/1TrSr5KvVw
#
#
# Tweet8
# Milan Ibrahimovic corre in spiaggia prima di tornare a Milanello (FOTO) - #Milan #Ibrahimovic #corre #spiaggia… https://t.co/AcT24omHub
#
#
# Tweet9
# RT @NacionDeportBo: ÉPICO🤪
#
# Zlatan a sus 41 años // Yo a mis 22 años
# #Ibrahimovic https://t.co/sOnt2Jgh4Z
#
#
# Tweet10
# RT @NacionDeportBo: ÉPICO🤪
#
# Zlatan a sus 41 años // Yo a mis 22 años
# #Ibrahimovic https://t.co/sOnt2Jgh4Z

# %% [markdown]
# ### 2. Tweepy

# %% [markdown]
# This package allows us to connect to the Twitter API in two ways: the `API` class (Twitter API v1.1), or the `Client`class (Twitter API v2.0). For simplicity, we will only use the `Client` class.

# %% [markdown]
# Let's authenticate:

# %%
client = tweepy.Client(bearer_token=bearer_token) #1.0 write and read, 2.0 read only

# %% [markdown]
# This time, we will exploit the API's query functionalities a little bit more in depth. In particular:
# * We will search for tweets from Ibra's official account only
# * We will exclude retweets
# * We'll grab tweets in English only

# %%
query = 'from:Ibra_official -is:retweet lang:en'

# %%
tweets = client.search_recent_tweets(query=query,max_results=10)

# %%
for i,tweet in enumerate(tweets.data):
    print(f'\n**Tweet {i+1}**\n',tweet.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 for i,tweet in enumerate(tweets.data):
#       2     print(f'\n**Tweet {i+1}**\n',tweet.text)
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# Notice that, even with Elevated access, we can only grab tweets from the last **7 days**, and in any case only up to **100 tweets**!
#
# The `paginator` object can help in this respect. Let's also grab some more metainformation about each tweet, and let's use logical operators within the query:

# %%
for i,tweet in enumerate(tweepy.Paginator(client.search_recent_tweets, query='(#zlatan #ibrahimovic) lang:en',
                              tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(limit=10000)):
    print(f'\n**Tweet {i+1}**\n',tweet.text)
    print(tweet.created_at)
    print(tweet.context_annotations)
# Out:
# **Tweet 1**
#  RT @Zlatankerala: Same age, different mentality
#
# #ibrahimovic #ronaldo #cristiano
# #CR7𓃵 #Saudi #AlNassr #CristianoRonaldo #zlatan https://t…
# 2023-01-06 19:04:09+00:00
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733774146434269186', 'name': 'Cristiano Ronaldo'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733774146434269186', 'name': 'Cristiano Ronaldo'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733774146434269186', 'name': 'Cristiano Ronaldo'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}]
#
# **Tweet 2**
#  RT @johnbonac1: My summer reading has just arrived! Adrenaline. Not giving up on my dream to meet @Ibra_official in person one day #Idol #Z…
# 2023-01-06 07:52:51+00:00
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}]
#
# **Tweet 3**
#  My summer reading has just arrived! Adrenaline. Not giving up on my dream to meet @Ibra_official in person one day #Idol #Zlatan #Ibrahimovic #Lion #ACMilan https://t.co/AumZCPpTOf
# 2023-01-06 03:34:56+00:00
# [{'domain': {'id': '12', 'name': 'Sports Team', 'description': 'A sports team organization, like Arsenal and the Boston Celtics'}, 'entity': {'id': '731226162496593920', 'name': 'AC Milan'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '731226162496593920', 'name': 'AC Milan'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}]
#
# **Tweet 4**
#  Zlatan is gonna be insane if he goes into Hollywood after his retirement.
# The type of body I wish Dwayne Johnson had, would had made beating his opponents look harder.
# The Rock na just Cheat 😂😂😂 #Hollywood #Zlatan #Ibrahimovic #DwayneJohnson #TheRock https://t.co/3gal1jCpqn
# 2023-01-05 21:14:49+00:00
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '809104437780168704', 'name': 'Dwayne Johnson', 'description': 'Dwayne Johnson'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id':
# [{'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}]
#
# **Tweet 18**
#  How Zlatan Ibrahimovic's difficult childhood made him the legend he is today! 🇸🇪
#
# #Zlatan #Ibrahimovic #sweden #football #soccer #fotboll https://t.co/JH44wFFz8A
# 2023-01-02 13:48:03+00:00
# [{'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733773808478232577', 'name': 'Zlatan Ibrahimovic'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}]
#
# **Tweet 19**
#  RT @abati1990: Army retires 120 generals, brigadiers, colonels, others
#
# #Nigeria #Yahoo #BigWiz #Yoruba #Ibrahimovic #JustDey #Brighton #M…
# 2023-01-02 00:28:35+00:00
# ...
#
# **Tweet 41**
#  Happy New Year! 🎆  2023 ✨
# @Ibra_official
# .
#
# #happynewyear #2023NewYear
# #ibrahimovic #acmilan #milan #zlatan #football #seriea #zlatanibrahimovic #messi #ronaldo #ibra  #neymar #المغرب_العربي #i̇ran #cr  #milano #المغرب
# #المدينة_المنورة
#   #المحرق #psg  #fútbol    #futbol https://t.co/vk6Duxy3lg
# 2023-01-01 01:55:24+00:00
# [{'domain': {'id': '6', 'name': 'Sports Event'}, 'entity': {'id': '1593035582413815808', 'name': 'RC Lens vs Paris Saint-Germain'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733774105166548992', 'name': 'Neymar '}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733774146434269186', 'name': 'Cristiano Ronaldo'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '733774222305038337', 'name': 'Lionel Messi'}}, {'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '12', 'name': 'Sports Team', 'description': 'A sports team organization, like Arsenal and the Boston Celtics'}, 'entity': {'id': '731226162496593920', 'name': 'AC Milan'}}, {'domain': {'id': '12', 'name': 'Sports Team', 'description': 'A sports team organization, like Arsenal and the Boston Celtics'}, 'entity': {'id': '731226166627966976', 'name': 'Paris Saint-Germain'}}, {'domain': {'id': '26', 'name': 'Sports League', 'description': ''}, 'entity': {'id': '731226213432221696', 'name': 'France - Soccer'}}, {'domain': {'id': '26', 'name': 'Sports League', 'description': ''}, 'entity': {'id': '733756534648274945', 'name': 'Ligue 1'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1319305164751163393', 'name': 'New Years Eve', 'description': 'This entity includes all conversations for New Years Eve for all years.'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1457786335108816904', 'name': "New Year's day", 'description': "This entity includes all conversations for the New Year's day for all years. "}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1593035582413815808', 'name': 'RC Lens vs Paris Saint-Germain'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1605626178454228992', 'name': 'New Years Eve 2023'}}, {'domain': {'id': '43', 'name': 'Soccer Match', 'description': 'Sports Event specific to Soccer matches'}, 'entity': {'id': '1593035582413815808', 'name': 'RC Lens vs Paris Saint-Germain'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733774105166548992', 'name': 'Neymar '}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733774146434269186', 'name': 'Cristiano Ronaldo'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '733774222305038337', 'name': 'Lionel Messi'}}, {'domain': {'id': '119', 'name': 'Holiday', 'description': 'Holidays like Christmas or Halloween'}, 'entity': {'id': '1319305164751163393', 'name': 'New Years Eve', 'description': 'This entity includes all conversations for New Years Eve for all years.'}}, {'domain': {'id': '119', 'name': 'Holiday', 'description': 'Holidays like Christmas or Halloween'}, 'entity': {'id': '1457786335108816904', 'name': "New Year's day", 'description': "This entity includes all conversations for the New Year's day for  ...
#
# **Tweet 42**
#  All man must answer to the creator and it R.I.P (2022) to the dead and GRACE to the living…2023 here we come🙏
#
# #Nigeria
#  #Yahoo
#  #BigWiz
# #Yoruba
# #Ibrahimovic
# #JustDey
#  #Brighton
#  #Mudryk
#  #Zlatan
# #WizkidXVotb
#  #31stofDecember
#  #Asake
#  #Ayefele
# #2023NewYear
# #2023promax
# 2022-12-31 20:46:30+00:00
# [{'domain': {'id': '3', 'name': 'TV Shows', 'description': 'Television shows from around the world'}, 'entity': {'id': '10053653751', 'name': 'Premier League'}}, {'domain': {'id': '6', 'name': 'Sports Event'}, 'entity': {'id': '1592676249805037569', 'name': 'Brighton & Hove Albion vs Arsenal FC'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1090863151829020672', 'name': 'Mykhailo Mudryk'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1503686100937715717', 'name': 'Asake'}}, {'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '26', 'name': 'Sports League', 'description': ''}, 'entity': {'id': '731226211804794880', 'name': 'England - Soccer'}}, {'domain': {'id': '26', 'name': 'Sports League', 'description': ''}, 'entity': {'id': '733756526872006656', 'name': 'Premier League'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1592676249805037569', 'name': 'Brighton & Hove Albion vs Arsenal FC'}}, {'domain': {'id': '43', 'name': 'Soccer Match', 'description': 'Sports Event specific to Soccer matches'}, 'entity': {'id': '1592676249805037569', 'name': 'Brighton & Hove Albion vs Arsenal FC'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557696802391859201', 'name': 'Entertainment & Leisure Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to movies, music, television, franchises, venues, theme parks, toys, tourism, hotels'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '54', 'name': 'Musician', 'description': 'A musician in the world, like Adele or Bob Dylan'}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '54', 'name': 'Musician', 'description': 'A musician in the world, like Adele or Bob Dylan'}, 'entity': {'id': '1503686100937715717', 'name': 'Asake'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '1090863151829020672', 'name': 'Mykhailo Mudryk'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756526872006656', 'name': 'Premier League'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847524658970636288', 'name': 'Music', 'description': 'Music and radio'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '131',  ...
#
# **Tweet 43**
#  RT @abati1990: 2022: Year of killings, deaths, pains - Over 8,000 persons killed across Nigeria
#
# #Nigeria #Yahoo #BigWiz #Yoruba #Ibrahimo…
# 2022-12-31 20:36:23+00:00
# [{'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557696802391859201', 'name': 'Entertainment & Leisure Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to movies, music, television, franchises, venues, theme parks, toys, tourism, hotels'}}, {'domain': {'id': '54', 'name': 'Musician', 'description': 'A musician in the world, like Adele or Bob Dylan'}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847524658970636288', 'name': 'Music', 'description': 'Music and radio'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1362824716570951682', 'name': 'Afrobeats'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1484491704430333955', 'name': 'Nigerian Artistes'}}, {'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '781974596752842752', 'name': 'Services'}}, {'domain': {'id': '47', 'name': 'Brand', 'description': 'Brands and Companies'}, 'entity': {'id': '10027474933', 'name': 'Yahoo!'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '10027474933', 'name': 'Yahoo!'}}]
#
# **Tweet 44**
#  RT @abati1990: Why some people are against me – Obi
#
# #Nigeria #Yahoo #BigWiz #Yoruba #Ibrahimovic #JustDey #Brighton #Mudryk #Zlatan #Wizk…
# 2022-12-31 18:25:57+00:00
# [{'domain': {'id': '3', 'name': 'TV Shows', 'description': 'Television shows from around the world'}, 'entity': {'id': '10053653751', 'name': 'Premier League'}}, {'domain': {'id': '6', 'name': 'Sports Event'}, 'entity': {'id': '1592676249805037569', 'name': 'Brighton & Hove Albion vs Arsenal FC'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '10', 'name': 'Person', 'description': 'Named people in the world like Nelson Mandela'}, 'entity': {'id': '1090863151829020672', 'name': 'Mykhailo Mudryk'}}, {'domain': {'id': '11', 'name': 'Sport', 'description': 'Types of sports, like soccer and basketball'}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '26', 'name': 'Sports League', 'description': ''}, 'entity': {'id': '731226211804794880', 'name': 'England - Soccer'}}, {'domain': {'id': '26', 'name': 'Sports League', 'description': ''}, 'entity': {'id': '733756526872006656', 'name': 'Premier League'}}, {'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Real world events. '}, 'entity': {'id': '1592676249805037569', 'name': 'Brighton & Hove Albion vs Arsenal FC'}}, {'domain': {'id': '43', 'name': 'Soccer Match', 'description': 'Sports Event specific to Soccer matches'}, 'entity': {'id': '1592676249805037569', 'name': 'Brighton & Hove Albion vs Arsenal FC'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557696802391859201', 'name': 'Entertainment & Leisure Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to movies, music, television, franchises, venues, theme parks, toys, tourism, hotels'}}, {'domain': {'id': '46', 'name': 'Business Taxonomy', 'description': 'Categories within Brand Verticals that narrow down the scope of Brands'}, 'entity': {'id': '1557697289971322880', 'name': 'Sports & Fitness Business', 'description': 'Brands, companies, advertisers and every non-person handle with the profit intent related to sports nutrition, athletic apparel, sports apps, fitness venues'}}, {'domain': {'id': '54', 'name': 'Musician', 'description': 'A musician in the world, like Adele or Bob Dylan'}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '60', 'name': 'Athlete', 'description': 'An athlete in the world, like Serena Williams or Lionel Messi'}, 'entity': {'id': '1090863151829020672', 'name': 'Mykhailo Mudryk'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756526872006656', 'name': 'Premier League'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '733756536430809088', 'name': 'Soccer'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847524658970636288', 'name': 'Music', 'description': 'Music and radio'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '847900493514891265', 'name': 'Sports', 'description': 'Sports'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '884820865740709888', 'name': 'Wizkid', 'description': 'Wizkid'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1090863151829020672', 'name': 'Mykhailo Mudryk'}}, {'domain': {'id': '131', 'name': 'Unified Twitter Taxonomy', 'description': 'A taxonomy of user interests. '}, 'entity': {'id': '1362824716570951682', 'name': 'Afrobeats'}}, {'domain ...

# %% [markdown]
# In particular, we grabbed information about **context annotations**, which are inferred based on semantic analysis (keywords, hashtags, handles, etc) of the Tweet text and result in domain and/or entity labels. Tweet annotations offer a way to understand contextual information about the Tweet itself.

# %% [markdown]
# In order to extract even more tweets and run some meaningful analyses, we would need to apply for the **Academic Research product track** within the Twitter Developer space. There are "hackier" ways to get historical Twitter data, that don't even require to directly connect to the Twitter API.

# %% [markdown]
# ### 3. Snscrape

# %% [markdown]
# Snscrape is a scraper for social networks. It can scrape Twitter, Facebook, Instagram, and many others, without any limits on the amount of data to be grabbed.
#
# Important disclaimer: if possible, it is always preferrable to scrape data using an **officially sanctioned API**, such as the one presented above. Scraping with other methods, albeit legal (in the case of public information), may result in excessive traffic on the scraped websites, and worsen user experience for other users.

# %%
query = '(#zlatan OR #ibrahimovic OR #zlatanibrahimovic OR #ibra) -has:links -is:retweet -to:Ibra_official -has:images -has:mentions -has:media lang:en'

# the scraped tweets, this is a generator (it does not return a single object, but an iterator object with a sequence of values)
scraped_tweets = sntwitter.TwitterSearchScraper(query).get_items()

# slicing the generator to keep only the first 100000 tweets
sliced_scraped_tweets = itertools.islice(scraped_tweets, 100000)

# convert to a DataFrame and keep only relevant columns
tweets_df = pd.DataFrame(sliced_scraped_tweets)[['user','date','likeCount','content']]
tweets_df
# Out:
#                                                     user  \
# 0      {'username': 'fly_foot', 'id': 231038016, 'dis...
# 1      {'username': 'officialwhypie', 'id': 150549924...
# 2      {'username': 'PkChelzard', 'id': 1067006464974...
# 3      {'username': 'globaltimesng', 'id': 4642102642...
# 4      {'username': 'NBA_Maillot', 'id': 133623780891...
# ...                                                  ...
# 99995  {'username': 'ImHughesy', 'id': 235279255, 'di...
# 99996  {'username': 'rmzn_aydnl32', 'id': 1168453112,...
# 99997  {'username': 'Patel_inc', 'id': 336946068, 'di...
# 99998  {'username': 'merlin2709', 'id': 7528700679442...
# 99999  {'username': 'sjwebber', 'id': 57417391, 'disp...
#
#                            date  likeCount  \
# 0     2023-01-08 10:43:11+00:00          3
# 1     2023-01-08 10:02:50+00:00          0
# 2     2023-01-08 08:20:08+00:00          0
# 3     2023-01-08 08:16:46+00:00          0
# 4     2023-01-08 07:48:05+00:00          0
# ...                         ...        ...
# 99995 2017-02-16 22:02:15+00:00          0
# 99996 2017-02-16 22:02:14+00:00          1
# 99997 2017-02-16 22:02:12+00:00          0
# 99998 2017-02-16 22:02:08+00:00          1
# 99999 2017-02-16 22:02:01+00:00          0
#
#                                                  content
# 0      Those players are the only players to score in...
# 1      #ZLATAN TOO OLD FOR PREMIER LEAGUE?!!!🤔- #Tota...
# 2      @UnlimitedEniola If playing for longer is a qu...
# 3      #Moment #Zlatan #Ibile #paused #performance to...
# 4      ⚽🇮🇹|New Tenue enfant #ACMilan Third 2022/2023\...
# ...                                                  ...
# 99995  Plenty of piss being boiled tonight #Zlatan⚽️⚽️⚽️
# 99996  Man of the match. Superb performance. #Zlatan ...
# 99997  Man utd suberb  goals from #Ibra #GGMU We are ...
# 99998  @FerrariNana11 #Ibra #Legend. The man is brill...
# 99999  6 FOOT 5!!!!! HARD AS FUCK #Zlatan #mufc #unit...
#
# [100000 rows x 4 columns]

# %% [markdown]
# Snscrape will start grabbing the most recent tweets first.

# %%
tweets_df.to_csv(r'H:\Data science\TwiZlatan\Twitter data.csv', index=False)

# %% [markdown]
# ### 4. Sentiment analysis

# %% [markdown]
# We now want to run a (very basic) sentiment analysis on the tweets we just scraped, to understand what is the public perspective on Zlatan. To do so, we first need to clean our data.

# %%
tweets_df = pd.read_csv(r'H:\Data science\TwiZlatan\Twitter data.csv')

# %% [markdown]
# We'll first extract the username from user information (which is a dictionary, but unconveniently saved as a string):

# %%
tweets_df['user'] = tweets_df['user'].apply(lambda x: x[x.find('username')+11:x.find('id')-3])

# %% [markdown]
# And then, let's remove punctuation and links that escaped the query:

# %%
tweets_df['content'] = tweets_df['content'].apply(lambda x: x.translate(str.maketrans('','',string.punctuation)))

# %%
tweets_df['content'] = tweets_df['content'].apply(lambda x: ' '.join(word for word in x.split(' ') if not word.startswith('https')))

# %%
tweets_df
# Out:
#                    user                       date  likeCount  \
# 0            'fly_foot'  2023-01-08 10:43:11+00:00          3
# 1      'officialwhypie'  2023-01-08 10:02:50+00:00          0
# 2          'PkChelzard'  2023-01-08 08:20:08+00:00          0
# 3       'globaltimesng'  2023-01-08 08:16:46+00:00          0
# 4         'NBA_Maillot'  2023-01-08 07:48:05+00:00          0
# ...                 ...                        ...        ...
# 99995       'ImHughesy'  2017-02-16 22:02:15+00:00          0
# 99996    'rmzn_aydnl32'  2017-02-16 22:02:14+00:00          1
# 99997       'Patel_inc'  2017-02-16 22:02:12+00:00          0
# 99998      'merlin2709'  2017-02-16 22:02:08+00:00          1
# 99999        'sjwebber'  2017-02-16 22:02:01+00:00          0
#
#                                                  content  polarity  \
# 0      Those players are the only players to score in...  0.000000
# 1      ZLATAN TOO OLD FOR PREMIER LEAGUE🤔 TotalFootba...  0.100000
# 2      UnlimitedEniola If playing for longer is a qua...  0.000000
# 3      Moment Zlatan Ibile paused performance to ‘dea...  0.000000
# 4      ⚽🇮🇹New Tenue enfant ACMilan Third 20222023\nAu...  0.000000
# ...                                                  ...       ...
# 99995   Plenty of piss being boiled tonight Zlatan⚽️⚽️⚽️  0.000000
# 99996  Man of the match Superb performance Zlatan Zla...  1.000000
# 99997  Man utd suberb  goals from Ibra GGMU We are wi...  0.000000
# 99998  FerrariNana11 Ibra Legend The man is brilliant...  0.900000
# 99999      6 FOOT 5 HARD AS FUCK Zlatan mufc united 👊🏻⚽️ -0.345833
#
#        subjectivity
# 0          1.000000
# 1          0.200000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ...             ...
# 99995      0.000000
# 99996      1.000000
# 99997      0.000000
# 99998      1.000000
# 99999      0.570833
#
# [100000 rows x 6 columns]

# %% [markdown]
# **TextBlob** is built on top of the most famous **[nltk](https://www.nltk.org/)** library. Both perform sentiment analysis via a rule-based classifier; this makes them faster than pre-trained models (such as [Flair](https://www.geeksforgeeks.org/flair-a-framework-for-nlp/)), but may worsen performance, because they have more difficulties in understanding sarcasm or jargon.

# %%
tweets_df[['polarity','subjectivity']] = tweets_df['content'].apply(lambda x: pd.Series(TextBlob(x).sentiment))
tweets_df
# Out:
#                    user                       date  likeCount  \
# 0            'fly_foot'  2023-01-08 10:43:11+00:00          3
# 1      'officialwhypie'  2023-01-08 10:02:50+00:00          0
# 2          'PkChelzard'  2023-01-08 08:20:08+00:00          0
# 3       'globaltimesng'  2023-01-08 08:16:46+00:00          0
# 4         'NBA_Maillot'  2023-01-08 07:48:05+00:00          0
# ...                 ...                        ...        ...
# 99995       'ImHughesy'  2017-02-16 22:02:15+00:00          0
# 99996    'rmzn_aydnl32'  2017-02-16 22:02:14+00:00          1
# 99997       'Patel_inc'  2017-02-16 22:02:12+00:00          0
# 99998      'merlin2709'  2017-02-16 22:02:08+00:00          1
# 99999        'sjwebber'  2017-02-16 22:02:01+00:00          0
#
#                                                  content  polarity  \
# 0      Those players are the only players to score in...  0.000000
# 1      ZLATAN TOO OLD FOR PREMIER LEAGUE🤔 TotalFootba...  0.100000
# 2      UnlimitedEniola If playing for longer is a qua...  0.000000
# 3      Moment Zlatan Ibile paused performance to ‘dea...  0.000000
# 4      ⚽🇮🇹New Tenue enfant ACMilan Third 20222023\nAu...  0.000000
# ...                                                  ...       ...
# 99995   Plenty of piss being boiled tonight Zlatan⚽️⚽️⚽️  0.000000
# 99996  Man of the match Superb performance Zlatan Zla...  1.000000
# 99997  Man utd suberb  goals from Ibra GGMU We are wi...  0.000000
# 99998  FerrariNana11 Ibra Legend The man is brilliant...  0.900000
# 99999      6 FOOT 5 HARD AS FUCK Zlatan mufc united 👊🏻⚽️ -0.345833
#
#        subjectivity
# 0          1.000000
# 1          0.200000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ...             ...
# 99995      0.000000
# 99996      1.000000
# 99997      0.000000
# 99998      1.000000
# 99999      0.570833
#
# [100000 rows x 6 columns]

# %% [markdown]
# * **Polarity** lies between -1 and 1; -1 means a negative statement, 1 a positive one.
# * **Subjectivity** lies between 0 and 1; 0 means factual information, 1 a subjective opinion.

# %%
print(type(tweets_df['content'].values))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Let's now create a (super basic) wordcloud:

# %%
stopwords = set(STOPWORDS) # Words we do not want to see in the wordcloud
stopwords.update(["Zlatan", "Ibra", "Ibrahimovic","n","S2EP45","Man"])

wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white", stopwords=stopwords).generate(np.array2string(tweets_df['content'].values))
plt.figure(figsize=(8, 6), dpi=80)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### References

# %% [markdown]
# * An [introduction to Twython](https://www.youtube.com/watch?v=7MVIfmjQERo&t=591s).
# * A [tutorial to use Tweepy and Snscrape](https://www.freecodecamp.org/news/python-web-scraping-tutorial/).
# * A [step-by-step tutorial for sentiment analysis on scraped Twitter data](https://www.youtube.com/watch?v=fQLa40L_BWA&t=0s).
# * The [official Twitter guide to advanced queries on its API](https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query).
# * A [Medium article to choose between different sentiment analysis packages](https://towardsdatascience.com/the-best-python-sentiment-analysis-package-1-huge-common-mistake-d6da9ad6cdeb).
# * A [DataCamp tutorial for generating wordclouds](https://www.datacamp.com/tutorial/wordcloud-python).
# * A [website to watch football for free](http://www.redditsoccerstreams.tv/) (I deny legal responsibility).

# %% [markdown]
# ![image2](images/Zlatan_facts.png)
